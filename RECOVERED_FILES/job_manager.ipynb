# %% [markdown]
# # Tufts HPC Job Manager
#
# This notebook helps you:
# 1. View available cluster resources
# 2. Check your current job sessions
# 3. Kill all your jobs (with confirmation)
#
# **IMPORTANT**: Run this on a compute node or login node, NOT in Cursor locally.

# %% [markdown]
# ## 1. Check Available Resources

# %%
#
# #currently on 8891
#  Check storage usage
# !echo "=== Storage Usage ==="
# !df -h /cluster/tufts/datalab
# !df -h /cluster/tufts/em212class
# !echo ""

# Check cluster partitions and resources
# !echo "=== Cluster Partitions ==="
# !sinfo -o "%P %a %l %D %c %m %G" | sed -n '1,30p'
# !echo ""

# Check GPU availability
# !echo "=== GPU Partitions ==="
# !sinfo -o "%P %a %l %D %c %m %G" | grep gpu
# !echo ""

# Check if hpctools is available
# !echo "=== HPC Tools ==="
# !module load hpctools 2>/dev/null && echo "hpctools loaded" || echo "hpctools not available"
# Out:
# === Storage Usage ===
# Filesystem                       Size  Used Avail Use% Mounted on
# 10.246.194.77:/projects/datalab  2.3T  2.3T  6.7G 100% /cluster/tufts/datalab
# Filesystem                          Size  Used Avail Use% Mounted on
# 10.246.194.78:/projects/em212class 1000G  8.9G  991G   1% /cluster/tufts/em212class
#
# === Cluster Partitions ===
# PARTITION AVAIL TIMELIMIT NODES CPUS MEMORY GRES
# interactive up 4:00:00 2 36 248000 (null)
# batch* up 7-00:00:00 71 36+ 120000+ (null)
# mpi up 7-00:00:00 70 36+ 120000+ (null)
# gpu up 7-00:00:00 1 64 190000 gpu:a100:2
# gpu up 7-00:00:00 10 64+ 756121+ gpu:a100:8
# gpu up 7-00:00:00 1 72 248000 gpu:p100:4
# largemem up 7-00:00:00 2 36+ 1000000 (null)
# preempt up 7-00:00:00 3 64+ 190000+ gpu:a100:2
# preempt up 7-00:00:00 9 64+ 756121+ gpu:a100:8
# preempt up 7-00:00:00 9 128 248000+ gpu:l40:4
# preempt up 7-00:00:00 1 64 368000 gpu:v100:3
# preempt up 7-00:00:00 1 72 248000 gpu:p100:4
# preempt up 7-00:00:00 1 72 256000 gpu:p100:6
# preempt up 7-00:00:00 1 64 168000 gpu:v100:2
# preempt up 7-00:00:00 1 64 184000 gpu:rtx_6000:2
# preempt up 7-00:00:00 20 80 92000 gpu:t4:4
# preempt up 7-00:00:00 1 128 1030000 gpu:rtx_6000ada:4
# preempt up 7-00:00:00 1 224 2060000 gpu:h100:3
# preempt up 7-00:00:00 4 128 510000 gpu:rtx_a5000:8
# preempt up 7-00:00:00 97 36+ 120000+ (null)
# preempt up 7-00:00:00 1 96 1030000 gpu:rtx_a6000:8
# preempt up 7-00:00:00 2 64+ 256000+ gpu:v100:4
# preempt up 7-00:00:00 1 128 1020000 gpu:l40s:4
#
# === GPU Partitions ===
# gpu up 7-00:00:00 1 64 190000 gpu:a100:2
# gpu up 7-00:00:00 10 64+ 756121+ gpu:a100:8
# gpu up 7-00:00:00 1 72 248000 gpu:p100:4
# preempt up 7-00:00:00 3 64+ 190000+ gpu:a100:2
# preempt up 7-00:00:00 9 64+ 756121+ gpu:a100:8
# preempt up 7-00:00:00 9 128 248000+ gpu:l40:4
# preempt up 7-00:00:00 1 64 368000 gpu:v100:3
# preempt up 7-00:00:00 1 72 248000 gpu:p100:4
# preempt up 7-00:00:00 1 72 256000 gpu:p100:6
# preempt up 7-00:00:00 1 64 168000 gpu:v100:2
# preempt up 7-00:00:00 1 64 184000 gpu:rtx_6000:2
# preempt up 7-00:00:00 20 80 92000 gpu:t4:4
# preempt up 7-00:00:00 1 128 1030000 gpu:rtx_6000ada:4
# preempt up 7-00:00:00 1 224 2060000 gpu:h100:3
# preempt up 7-00:00:00 4 128 510000 gpu:rtx_a5000:8
# preempt up 7-00:00:00 1 96 1030000 gpu:rtx_a6000:8
# preempt up 7-00:00:00 2 64+ 256000+ gpu:v100:4
# preempt up 7-00:00:00 1 128 1020000 gpu:l40s:4
#
# === HPC Tools ===
# hpctools loaded

# %% [markdown]
# ## 2. Check Your Current Jobs

# %%
# Show ONLY your current jobs (zwu09)
# !echo "=== Your Current Jobs (zwu09 only) ==="
# !squeue -u zwu09
# !echo ""

# Count jobs by state for zwu09 only
# !echo "=== Job Summary (zwu09 only) ==="
# !squeue -u zwu09 --format="%.18i %.9P %.8j %.8u %.2t %.10M %.6D %R" --noheader | awk '{print $5}' | sort | uniq -c
# !echo ""

# Show detailed info for running jobs (zwu09 only)
# !echo "=== Running Job Details (zwu09 only) ==="
# !squeue -u zwu09 --format="%.18i %.9P %.8j %.8u %.2t %.10M %.6D %R" --noheader | grep ' R ' | while read line; do
!    jobid=$(echo $line | awk '{print $1}')
!    echo "Job $jobid:"
!    scontrol show jobid -dd $jobid | grep -E "(JobId|JobName|UserId|State|RunTime|TimeLimit|NodeList|NumNodes|NumCPUs|ReqMem|GRES)"
!    echo "---"
# !done
# Out:
# === Your Current Jobs (zwu09 only) ===
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#           15655472       gpu     bash    zwu09  R      14:17      1 cc1gpu005
#
# === Job Summary (zwu09 only) ===
#       1 R
#
# === Running Job Details (zwu09 only) ===
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# Job :
# JobId=9699735 JobName=launch_experiment.sh
#    UserId=areddy05(34017) GroupId=areddy05(7786) MCS_label=N/A
#    JobState=PENDING Reason=ReqNodeNotAvail,_May_be_reserved_for_other_job Dependency=(null)
#    RunTime=00:00:00 TimeLimit=00:15:00 TimeMin=N/A
#    ReqNodeList=p1cmp010 ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15579658 JobName=bash
#    UserId=zhuang12(31612) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=6-11:14:24 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp001
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp001 CPU_IDs=114-115 Mem=30720 GRES=
# JobId=15586676 JobName=run37
#    UserId=mzaidi01(31503) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-04:27:35 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp112
#    NumNodes=1 NumCPUs=110 NumTasks=110 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp112 CPU_IDs=0-81,98-125 Mem=819200 GRES=
# JobId=15586678 JobName=run38
#    UserId=mzaidi01(31503) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-05:40:51 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp084
#    NumNodes=1 NumCPUs=90 NumTasks=90 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp084 CPU_IDs=0-89 Mem=716800 GRES=
# JobId=15598955 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=4-06:59:16 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu004 ExcNodeList=(null)
#    NodeList=cc1gpu004
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu004 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:2)
# JobId=15598964 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=4-06:53:46 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu005 ExcNodeList=(null)
#    NodeList=cc1gpu005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu005 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15601931 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=4-01:00:29 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu001 ExcNodeList=(null)
#    NodeList=cc1gpu001
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu001 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15602490 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-23:25:19 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu002 ExcNodeList=(null)
#    NodeList=cc1gpu002
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu002 CPU_IDs=0-1,18-23 Mem=131072 GRES=gpu:a100:1(IDX:1)
# JobId=15603641 JobName=bash
#    UserId=zhuang12(31612) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-20:50:30 TimeLimit=5-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp073
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:p100:1
#      Nodes=p1cmp073 CPU_IDs=36-37 Mem=30720 GRES=gpu:p100:1(IDX:1)
# JobId=15606464 ArrayJobId=15605963 ArrayTaskId=500 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp011
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp011 CPU_IDs=0 Mem=4096 GRES=
# JobId=15606466 ArrayJobId=15605963 ArrayTaskId=502 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp011
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp011 CPU_IDs=2 Mem=4096 GRES=
# JobId=15606476 ArrayJobId=15605963 ArrayTaskId=512 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp011
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp011 CPU_IDs=12 Mem=4096 GRES=
# JobId=15606485 ArrayJobId=15605963 ArrayTaskId=521 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=4 Mem=4096 GRES=
# JobId=15606494 ArrayJobId=15605963 ArrayTaskId=530 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=13 Mem=4096 GRES=
# JobId=15606505 ArrayJobId=15605963 ArrayTaskId=541 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=24 Mem=4096 GRES=
# JobId=15606507 ArrayJobId=15605963 ArrayTaskId=543 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=26 Mem=4096 GRES=
# JobId=15606511 ArrayJobId=15605963 ArrayTaskId=547 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=30 Mem=4096 GRES=
# JobId=15606515 ArrayJobId=15605963 ArrayTaskId=551 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=34 Mem=4096 GRES=
# JobId=15606528 ArrayJobId=15605963 ArrayTaskId=564 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp005
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp005 CPU_IDs=2-3 Mem=4096 GRES=
# JobId=15606584 ArrayJobId=15605963 ArrayTaskId=620 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=3 Mem=4096 GRES=
# JobId=15606585 ArrayJobId=15605963 ArrayTaskId=621 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=6 Mem=4096 GRES=
# JobId=15606591 ArrayJobId=15605963 ArrayTaskId=627 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=12 Mem=4096 GRES=
# JobId=15606592 ArrayJobId=15605963 ArrayTaskId=628 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=13 Mem=4096 GRES=
# JobId=15606597 ArrayJobId=15605963 ArrayTaskId=633 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=18 Mem=4096 GRES=
# JobId=15606598 ArrayJobId=15605963 ArrayTaskId=634 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=19 Mem=4096 GRES=
# JobId=15606600 ArrayJobId=15605963 ArrayTaskId=636 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=21 Mem=4096 GRES=
# JobId=15606602 ArrayJobId=15605963 ArrayTaskId=638 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=23 Mem=4096 GRES=
# JobId=15606603 ArrayJobId=15605963 ArrayTaskId=639 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=24 Mem=4096 GRES=
# JobId=15606606 ArrayJobId=15605963 ArrayTaskId=642 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=27 Mem=4096 GRES=
# JobId=15606608 ArrayJobId=15605963 ArrayTaskId=644 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=29 Mem=4096 GRES=
# JobId=15606609 ArrayJobId=15605963 ArrayTaskId=645 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=30 Mem=4096 GRES=
# JobId=15606612 ArrayJobId=15605963 ArrayTaskId=648 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=33 Mem=4096 GRES=
# JobId=15606613 ArrayJobId=15605963 ArrayTaskId=649 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=34 Mem=4096 GRES=
# JobId=15606696 ArrayJobId=15605963 ArrayTaskId=731 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:21:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=4 Mem=4096 GRES=
# JobId=15605963 ArrayJobId=15605963 ArrayTaskId=961 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=COMPLETED Reason=None Dependency=(null)
#    RunTime=00:00:04 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp012
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp012 CPU_IDs=58-59 Mem=4096 GRES=
# JobId=15608651 ArrayJobId=15608620 ArrayTaskId=9 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:51:55 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp036
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp036 CPU_IDs=54-61 Mem=20480 GRES=
# JobId=15609296 ArrayJobId=15608620 ArrayTaskId=24 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:07:43 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp013
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp013 CPU_IDs=82-89 Mem=20480 GRES=
# JobId=15609307 ArrayJobId=15608620 ArrayTaskId=28 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:05:43 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp012
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp012 CPU_IDs=60-63,110-113 Mem=20480 GRES=
# JobId=15609308 ArrayJobId=15608620 ArrayTaskId=29 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:05:43 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=2-3,10-15 Mem=20480 GRES=
# JobId=15610543 ArrayJobId=15609375 ArrayTaskId=5 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:17:12 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=40-47,52-55,112-115 Mem=20480 GRES=
# JobId=15610545 ArrayJobId=15609375 ArrayTaskId=7 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:17:12 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=56-65,94-97,100-101 Mem=20480 GRES=
# JobId=15610671 ArrayJobId=15609375 ArrayTaskId=9 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:13:11 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp013
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp013 CPU_IDs=18-19,100-113 Mem=20480 GRES=
# JobId=15610709 ArrayJobId=15609375 ArrayTaskId=23 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:07:10 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=64-69,72-77,88-89,92-93 Mem=20480 GRES=
# JobId=15610710 ArrayJobId=15609375 ArrayTaskId=24 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:07:10 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=0-3,6-17 Mem=20480 GRES=
# JobId=15610713 ArrayJobId=15609375 ArrayTaskId=27 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:07:10 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=84-99 Mem=20480 GRES=
# JobId=15610723 ArrayJobId=15609375 ArrayTaskId=30 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:05:09 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=40-55 Mem=20480 GRES=
# JobId=15610950 ArrayJobId=15609375 ArrayTaskId=36 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:28:59 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp006
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp006 CPU_IDs=52-55,58-63,78-79,94-95,122-123 Mem=20480 GRES=
# JobId=15610951 ArrayJobId=15609375 ArrayTaskId=37 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:28:59 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp010
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp010 CPU_IDs=4-7,20-25,28-33 Mem=20480 GRES=
# JobId=15610953 ArrayJobId=15609375 ArrayTaskId=39 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:28:59 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp022
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp022 CPU_IDs=0-3,16-19,38-45 Mem=20480 GRES=
# JobId=15610960 ArrayJobId=15609375 ArrayTaskId=41 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:26:59 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp022
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp022 CPU_IDs=46-59,86-87 Mem=20480 GRES=
# JobId=15611641 ArrayJobId=15609375 ArrayTaskId=43 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:08:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=0-1,8-9,18-21,24-25,30-31,52-55 Mem=20480 GRES=
# JobId=15611642 ArrayJobId=15609375 ArrayTaskId=44 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:08:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=18-29,54-57 Mem=20480 GRES=
# JobId=15612071 ArrayJobId=15609375 ArrayTaskId=46 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-05:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp017
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp017 CPU_IDs=38-39,82-95 Mem=20480 GRES=
# JobId=15612076 ArrayJobId=15609375 ArrayTaskId=49 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-05:46:51 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=6-9,14-15,20-21,28-33,36-37 Mem=20480 GRES=
# JobId=15609375 ArrayJobId=15609375 ArrayTaskId=57 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=COMPLETED Reason=None Dependency=(null)
#    RunTime=00:02:34 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=4-5,10-13,22-27,34-35,38-39 Mem=20480 GRES=
# JobId=15608620 ArrayJobId=15608620 ArrayTaskId=74 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=FAILED Reason=NonZeroExitCode Dependency=(null)
#    RunTime=00:00:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp033
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp033 CPU_IDs=64-65,70-73,78-79 Mem=20480 GRES=
# JobId=15615967 JobName=1_2a_NG15_more
#    UserId=amalna01(33643) GroupId=amalna01(7236) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-11:26:43 TimeLimit=6-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp041
#    NumNodes=1 NumCPUs=3 NumTasks=3 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp041 CPU_IDs=120-121,124-125 Mem=102400 GRES=
# JobId=15616459 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:05:47 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=s1cmp004 ExcNodeList=(null)
#    NodeList=s1cmp004
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp004 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15616460 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:05:47 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=s1cmp001 ExcNodeList=(null)
#    NodeList=s1cmp001
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp001 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15616461 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-10:03:07 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=s1cmp005 ExcNodeList=(null)
#    NodeList=s1cmp005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp005 CPU_IDs=80-81,86-87,94-95,110-111 Mem=131072 GRES=gpu:a100:1(IDX:5)
# JobId=15617153 JobName=sys/dashboard/sys/jupyternotebook
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-10:08:47 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp010
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp010 CPU_IDs=22-25 Mem=16000 GRES=
# JobId=15617199 ArrayJobId=15617196 ArrayTaskId=3 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp036
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp036 CPU_IDs=20-21,42-43,46-53,114-117 Mem=20480 GRES=
# JobId=15617205 ArrayJobId=15617196 ArrayTaskId=9 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp039
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp039 CPU_IDs=8-9,84-87,94-103 Mem=20480 GRES=
# JobId=15617206 ArrayJobId=15617196 ArrayTaskId=10 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp040
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp040 CPU_IDs=0-1,8-11,16-17,22-27,30-31 Mem=20480 GRES=
# JobId=15617208 ArrayJobId=15617196 ArrayTaskId=12 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp021
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp021 CPU_IDs=74-75,90-91,98-109 Mem=20480 GRES=
# JobId=15617210 ArrayJobId=15617196 ArrayTaskId=14 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp021
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp021 CPU_IDs=38-51,62-63 Mem=20480 GRES=
# JobId=15617214 ArrayJobId=15617196 ArrayTaskId=18 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp043
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp043 CPU_IDs=0-5,16-23,30-31 Mem=20480 GRES=
# JobId=15617218 ArrayJobId=15617196 ArrayTaskId=22 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp045
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp045 CPU_IDs=16-31 Mem=20480 GRES=
# JobId=15617220 ArrayJobId=15617196 ArrayTaskId=24 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp001
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp001 CPU_IDs=2-11,14-19 Mem=20480 GRES=
# JobId=15617223 ArrayJobId=15617196 ArrayTaskId=27 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp001
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp001 CPU_IDs=56-67,76-77,84-85 Mem=20480 GRES=
# JobId=15617224 ArrayJobId=15617196 ArrayTaskId=28 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=2-5,8-11,22-29 Mem=20480 GRES=
# JobId=15617225 ArrayJobId=15617196 ArrayTaskId=29 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=30-37,40-47 Mem=20480 GRES=
# JobId=15617226 ArrayJobId=15617196 ArrayTaskId=30 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=64-79 Mem=20480 GRES=
# JobId=15617228 ArrayJobId=15617196 ArrayTaskId=32 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=96-111 Mem=20480 GRES=
# JobId=15617229 ArrayJobId=15617196 ArrayTaskId=33 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=48-49,56-63,112-117 Mem=20480 GRES=
# JobId=15617230 ArrayJobId=15617196 ArrayTaskId=34 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=2-3,22-35 Mem=20480 GRES=
# JobId=15617231 ArrayJobId=15617196 ArrayTaskId=35 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=36-39,50-51,62-63,90-91,94-95,98-99,120-121 Mem=20480 GRES=
# JobId=15617233 ArrayJobId=15617196 ArrayTaskId=37 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=38-39,50-51,90-91,102-105,110-115 Mem=20480 GRES=
# JobId=15617234 ArrayJobId=15617196 ArrayTaskId=38 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=66-71,74-81,84-85 Mem=20480 GRES=
# JobId=15617235 ArrayJobId=15617196 ArrayTaskId=39 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=42-49,58-59,102-105,114-115 Mem=20480 GRES=
# JobId=15617236 ArrayJobId=15617196 ArrayTaskId=40 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:52:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp033
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp033 CPU_IDs=2-13,16-19 Mem=20480 GRES=
# JobId=15617196 ArrayJobId=15617196 ArrayTaskId=69 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=FAILED Reason=NonZeroExitCode Dependency=(null)
#    RunTime=00:00:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=0-5,10-13,16-19,22-23 Mem=20480 GRES=
# JobId=15617687 JobName=sys/dashboard/sys/jupyterlab
#    UserId=lbhara01(34408) GroupId=lbhara01(8198) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-08:45:39 TimeLimit=4-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp010
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp010 CPU_IDs=20 Mem=32000 GRES=
# JobId=15623109 JobName=1_2a_NG15_more1
#    UserId=amalna01(33643) GroupId=amalna01(7236) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-03:29:52 TimeLimit=6-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp009
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=s1cmp009 CPU_IDs=122-123 Mem=20480 GRES=
# JobId=15634230 JobName=1_2a_NG15_more2
#    UserId=amalna01(33643) GroupId=amalna01(7236) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-11:02:51 TimeLimit=6-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp053
#    NumNodes=1 NumCPUs=5 NumTasks=5 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp053 CPU_IDs=50-55 Mem=102400 GRES=
# JobId=15634410 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-10:22:20 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu001 ExcNodeList=(null)
#    NodeList=cc1gpu001
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu001 CPU_IDs=56-63 Mem=131072 GRES=gpu:a100:1(IDX:1)
# JobId=15634970 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-09:08:14 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu005 ExcNodeList=(null)
#    NodeList=cc1gpu005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu005 CPU_IDs=56-63 Mem=131072 GRES=gpu:a100:1(IDX:2)
# JobId=15635375 ArrayJobId=15635246 ArrayTaskId=2 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-09:18:17 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=30-41,50-53,64-65,72-73,82-83,86-95 Mem=20480 GRES=
# JobId=15636317 ArrayJobId=15635246 ArrayTaskId=3 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:29:46 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp012
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp012 CPU_IDs=4-5,8-11,18-19,42-47,52-53,58-59,90-93,106-109,114-119 Mem=20480 GRES=
# JobId=15635558 JobName=sys/dashboard/sys/jupyternotebook
#    UserId=jlin20(33203) GroupId=jlin20(5951) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-09:02:34 TimeLimit=5-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp008
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp008 CPU_IDs=0-3 Mem=110000 GRES=
# JobId=15636313 JobName=Etran_SKCongWRlayerN
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:30:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp005 CPU_IDs=52-59 Mem=65536 GRES=gpu:a100:1(IDX:4)
# JobId=15636320 JobName=Etran_SKCongWRlayerN
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:28:57 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp005 CPU_IDs=44-51 Mem=65536 GRES=gpu:a100:1(IDX:2)
# JobId=15636351 ArrayJobId=15635246 ArrayTaskId=5 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:19:43 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp011
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp011 CPU_IDs=14-17,22-23,34-35,44-47,56-63,68-71,86-87,96-97,102-103,108-109 Mem=20480 GRES=
# JobId=15636416 ArrayJobId=15635246 ArrayTaskId=7 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:09:40 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=6-17,48-49,56-59,78-79,82-83,96-97,102-109 Mem=20480 GRES=
# JobId=15636417 ArrayJobId=15635246 ArrayTaskId=8 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:09:40 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=4-7,16-17,22-23,26-29,32-37,42-47,76-77,80-81,88-89,98-99 Mem=20480 GRES=
# JobId=15636441 ArrayJobId=15635246 ArrayTaskId=10 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:05:39 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp019
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp019 CPU_IDs=0-3,14-15,22-27,36-39,58-59,64-69,72-75,82-85 Mem=20480 GRES=
# JobId=15636449 ArrayJobId=15635246 ArrayTaskId=11 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:03:38 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=4-5,10-11,24-27,34-35,38-39,66-69,80-83,100-103,106-113 Mem=20480 GRES=
# JobId=15636582 ArrayJobId=15635246 ArrayTaskId=12 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:43:35 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp065
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp065 CPU_IDs=2-3,10-13,16-17,20-23,26-33,36-37,40-41,50-51,60-65 Mem=20480 GRES=
# JobId=15636648 ArrayJobId=15635246 ArrayTaskId=15 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:37:33 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp007
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp007 CPU_IDs=0-5,26-27,32-33,36-37,40-41,54-55,90-105 Mem=20480 GRES=
# JobId=15636760 ArrayJobId=15635246 ArrayTaskId=17 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:25:31 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp014
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp014 CPU_IDs=0-31 Mem=20480 GRES=
# JobId=15636761 ArrayJobId=15635246 ArrayTaskId=18 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:25:31 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp016
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp016 CPU_IDs=0-31 Mem=20480 GRES=
# JobId=15636762 ArrayJobId=15635246 ArrayTaskId=19 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:25:31 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp036
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp036 CPU_IDs=18-19,64-93 Mem=20480 GRES=
# JobId=15636772 ArrayJobId=15635246 ArrayTaskId=20 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:23:31 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp005
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp005 CPU_IDs=0-1,24-25,32-37,42-43,64-65,68-71,76-89 Mem=20480 GRES=
# JobId=15636960 ArrayJobId=15635246 ArrayTaskId=22 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-05:49:24 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp016
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp016 CPU_IDs=32-39,42-43,48-49,52-67,76-79 Mem=20480 GRES=
# JobId=15636970 JobName=ImperfectCSI
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-05:48:19 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=cc1gpu004
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu004 CPU_IDs=56-63 Mem=65536 GRES=gpu:a100:1(IDX:1)
# JobId=15636979 JobName=UA_GumbelSoftmax
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-05:47:37 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=cc1gpu002
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu002 CPU_IDs=2-9 Mem=65536 GRES=gpu:a100:1(IDX:0)
# JobId=15636985 JobName=ImperfectCSI
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
# ...
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655486 ArrayJobId=15655486 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655487 JobName=A_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655490 ArrayJobId=15653485 ArrayTaskId=213 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:09:58 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp006
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp006 CPU_IDs=88-89 Mem=32768 GRES=gpu:a100:1(IDX:1)
# JobId=15655489 ArrayJobId=15655489 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655492 ArrayJobId=15653485 ArrayTaskId=214 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:09:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp003
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp003 CPU_IDs=0-1 Mem=32768 GRES=gpu:a100:1(IDX:0)
# JobId=15655491 JobName=A_Find_ANN_1K_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655493 ArrayJobId=15653485 ArrayTaskId=215 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:09:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp004 CPU_IDs=56-57 Mem=32768 GRES=gpu:a100:1(IDX:1)
# JobId=15655496 ArrayJobId=15653485 ArrayTaskId=216 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:08:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp015
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:rtx_a5000:1
#      Nodes=s1cmp015 CPU_IDs=0-1 Mem=32768 GRES=gpu:rtx_a5000:1(IDX:1)
# JobId=15655494 JobName=T_Find_ANN_1K_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655513 ArrayJobId=15653485 ArrayTaskId=217 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:03:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp007
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp007 CPU_IDs=84-85 Mem=32768 GRES=gpu:a100:1(IDX:0)
# JobId=15655497 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655498 ArrayJobId=15655498 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655500 ArrayJobId=15655500 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655501 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655502 JobName=vscode.slurm
#    UserId=kheuto01(32122) GroupId=kheuto01(5594) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:06:22 TimeLimit=13:25:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp013
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:rtx_a5000:1
#      Nodes=s1cmp013 CPU_IDs=0-1,64-65 Mem=256000 GRES=gpu:rtx_a5000:1(IDX:0)
# JobId=15655503 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15652426 ArrayJobId=15652426 ArrayTaskId=2 JobName=transjob_05_060_2025_JulAug.sh
#    UserId=acampi02(33741) GroupId=acampi02(7344) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:05:57 TimeLimit=08:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp[005-007,010-015,021-022,035,038-040],p1cmp045
#    NumNodes=16 NumCPUs=16 NumTasks=16 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp005 CPU_IDs=38-39 Mem=32768 GRES=
#      Nodes=d1cmp006 CPU_IDs=20-21 Mem=32768 GRES=
#      Nodes=d1cmp007 CPU_IDs=16-17 Mem=32768 GRES=
#      Nodes=d1cmp010 CPU_IDs=60-61 Mem=32768 GRES=
#      Nodes=d1cmp011 CPU_IDs=122-123 Mem=32768 GRES=
#      Nodes=d1cmp012 CPU_IDs=82-83 Mem=32768 GRES=
#      Nodes=d1cmp013 CPU_IDs=24-25 Mem=32768 GRES=
#      Nodes=d1cmp014 CPU_IDs=94-95 Mem=32768 GRES=
#      Nodes=d1cmp015 CPU_IDs=62-63 Mem=32768 GRES=
#      Nodes=d1cmp021 CPU_IDs=60-61 Mem=32768 GRES=
#      Nodes=d1cmp022 CPU_IDs=34-35 Mem=32768 GRES=
#      Nodes=d1cmp035 CPU_IDs=4-5 Mem=32768 GRES=
#      Nodes=d1cmp038 CPU_IDs=40-41 Mem=32768 GRES=
#      Nodes=d1cmp039 CPU_IDs=16-17 Mem=32768 GRES=
#      Nodes=d1cmp040 CPU_IDs=72-73 Mem=32768 GRES=
#      Nodes=p1cmp045 CPU_IDs=10-11 Mem=32768 GRES=
# JobId=15655506 ArrayJobId=15655506 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655509 ArrayJobId=15655509 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15652427 ArrayJobId=15652427 ArrayTaskId=2 JobName=transjob_05_061_2025_JulAug.sh
#    UserId=acampi02(33741) GroupId=acampi02(7344) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=08:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=16-16 NumCPUs=16 NumTasks=16 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655511 JobName=sys/dashboard/sys/jupyternotebook
#    UserId=eharve06(32875) GroupId=eharve06(6607) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:03:40 TimeLimit=12:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp010
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp010 CPU_IDs=18-19,21,26 Mem=16000 GRES=
# JobId=15655512 JobName=sys/dashboard/sys/jupyter_class
#    UserId=hlee37(34735) GroupId=hlee37(8554) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:03:34 TimeLimit=04:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp035
#    NumNodes=1 NumCPUs=2 NumTasks=2 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp035 CPU_IDs=2-3 Mem=1000 GRES=
# JobId=15655515 ArrayJobId=15653485 ArrayTaskId=218 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:02:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp001
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp001 CPU_IDs=8-9 Mem=32768 GRES=gpu:a100:1(IDX:1)
# JobId=15655516 ArrayJobId=15653485 ArrayTaskId=219 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:01:56 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp001
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp001 CPU_IDs=102-103 Mem=32768 GRES=gpu:a100:1(IDX:6)
# JobId=15655517 ArrayJobId=15653485 ArrayTaskId=220 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:01:56 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp001
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp001 CPU_IDs=104-105 Mem=32768 GRES=gpu:a100:1(IDX:7)
# JobId=15655520 ArrayJobId=15653485 ArrayTaskId=221 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:01:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp003
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp003 CPU_IDs=64-65 Mem=32768 GRES=gpu:a100:1(IDX:2)
# JobId=15655518 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655519 ArrayJobId=15655519 ArrayTaskId=1-6 JobName=picc-rl-array
#    UserId=bmille12(34074) GroupId=bmille12(7856) MCS_label=N/A
#    JobState=PENDING Reason=Resources Dependency=(null)
#    RunTime=00:00:00 TimeLimit=06:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=64 NumTasks=1 CPUs/Task=64 ReqB:S:C:T=0:0:*:*
# JobId=15655521 ArrayJobId=15653485 ArrayTaskId=222 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:01:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp003
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp003 CPU_IDs=118-119 Mem=32768 GRES=gpu:a100:1(IDX:5)
# JobId=15655522 ArrayJobId=15653485 ArrayTaskId=223 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:01:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp003
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp003 CPU_IDs=120-121 Mem=32768 GRES=gpu:a100:1(IDX:6)
# JobId=15655526 ArrayJobId=15653485 ArrayTaskId=224 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:00:22 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp050
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:l40:1
#      Nodes=d1cmp050 CPU_IDs=112-113 Mem=32768 GRES=gpu:l40:1(IDX:0)
# JobId=15655523 ArrayJobId=15655523 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655524 ArrayJobId=15655524 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655525 ArrayJobId=15655525 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15653485 ArrayJobId=15653485 ArrayTaskId=225-499%16 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=PENDING Reason=JobArrayTaskLimit Dependency=(null)
#    RunTime=00:00:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655527 ArrayJobId=15655527 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=None Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# ---
# /bin/bash: -c: line 0: syntax error near unexpected token `done'
# /bin/bash: -c: line 0: `done'

# %% [markdown]
# ## 3. Kill All Your Jobs (CONFIRMATION REQUIRED)
#
# **⚠️ WARNING: This will cancel ALL your jobs! ⚠️**
#
# Run the cell below and confirm when prompted.

# %%
# Simple job killer - specify job IDs manually
# COMMENTED OUT FOR "RUN ALL" - Uncomment if you need to kill jobs
"""
print("=== Manual Job Cancellation ===")
print("Enter job IDs to cancel (comma-separated, or 'all' for all zwu09 jobs)")
print("Example: 15655172,15655173")
print("Or type 'all' to cancel all zwu09 jobs")
print()

# Get job IDs from user
job_input = input("Job IDs to cancel: ").strip()

if job_input.lower() == 'all':
    print("🔄 Cancelling all zwu09 jobs...")
    result = subprocess.run(['scancel', '-u', 'zwu09'], capture_output=True, text=True, shell=True)
    if result.returncode == 0:
        print("✅ All zwu09 jobs cancelled!")
    else:
        print(f"❌ Error: {result.stderr}")
else:
    # Parse job IDs
    job_ids = [jid.strip() for jid in job_input.split(',') if jid.strip()]
    
    if not job_ids:
        print("❌ No valid job IDs provided.")
    else:
        print(f"🔄 Cancelling jobs: {', '.join(job_ids)}")
        
        # Cancel each job individually
        for job_id in job_ids:
            result = subprocess.run(['scancel', job_id], capture_output=True, text=True, shell=True)
            if result.returncode == 0:
                print(f"✅ Job {job_id} cancelled")
            else:
                print(f"❌ Error cancelling job {job_id}: {result.stderr}")

print("\n=== Verification ===")
# !squeue -u zwu09
"""

print("ℹ️  Job killer commented out for 'Run All'. Uncomment if needed.")
# Out:
# ℹ️  Job killer commented out for 'Run All'. Uncomment if needed.

# %% [markdown]
# ## 4. Quick Command Reference MUST ONLY BE RUN AT https://ondemand.pax.tufts.edu/pun/sys/shell/ssh/login.pax.tufts.edu
#
# **Manual commands to run in terminal:**
#
# ```bash
# # Show your jobs
# squeue -u zwu09
#
# # Cancel specific job by ID
# scancel 15655172
#
# # Cancel multiple jobs by ID
# scancel 15655172 15655173 15655174
#
# # Cancel ALL your jobs
# scancel -u zwu09
#
# # Show job details
# scontrol show jobid -dd 15655172
# ```

# %% [markdown]
# ## 5. GPU Demos and Cool Stuff
#
# Now let's test your GPU and run some awesome demos!

# %%
# Check GPU availability and info
# !echo "=== GPU Information ==="
# !nvidia-smi
# !echo ""

# Check PyTorch CUDA availability
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU count: {torch.cuda.device_count()}")
    print(f"Current GPU: {torch.cuda.current_device()}")
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
else:
    print("❌ CUDA not available - check your GPU allocation!")
# Out:
# === GPU Information ===
# Thu Sep 11 21:21:29 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.154.05             Driver Version: 535.154.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-PCIE-40GB          On  | 00000000:1C:00.0 Off |                    0 |
# | N/A   33C    P0              41W / 250W |      3MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
#
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# CUDA version: 12.1
# GPU count: 1
# Current GPU: 0
# GPU name: NVIDIA A100-PCIE-40GB
# GPU memory: 39.6 GB

# %%
# Check datalab space and clean up if needed
# !echo "=== Datalab Storage Check ==="
# !df -h /cluster/tufts/datalab
# !echo ""
# !echo "=== Your datalab directory contents ==="
# !ls -la /cluster/tufts/datalab/zwu09/
# !echo ""
# !echo "=== Directory sizes ==="
# !du -sh /cluster/tufts/datalab/zwu09/* 2>/dev/null | sort -hr | head -10
# Out:
# === Datalab Storage Check ===
# Filesystem                       Size  Used Avail Use% Mounted on
# 10.246.194.77:/projects/datalab  2.3T  2.3T  6.7G 100% /cluster/tufts/datalab
#
# === Your datalab directory contents ===
# total 5220231
# drwxrws---  2 zwu09    datalab       4096 Sep 11 19:39 .
# drwxrwsr-x 92 pflora01 datalab       4096 Sep 10 18:53 ..
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 bin
# drwxr-sr-x  2 zwu09    datalab       4096 May  2 06:16 .cache
# drwxrwsr-x  2 zwu09    datalab       4096 Sep 11 21:19 caches
# drwxrwxr-x  2 zwu09    datalab       4096 May  2 07:50 dateutil
# drwxr-sr-x  2 zwu09    datalab       4096 Sep 11 19:20 envs
# -rw-r--r--  1 zwu09    datalab 5343667350 May  9 05:36 goodreads_reviews_dedup.json.gz
# drwxr-sr-x  2 zwu09    datalab       4096 Sep 11 17:32 .ipynb_checkpoints
# -rw-rw-r--  1 zwu09    datalab        312 Sep 11 19:22 jlab_8890.log
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 joblib
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 joblib-1.4.2.dist-info
# -rw-r--r--  1 zwu09    datalab       2313 May  2 01:43 kernel_paths.txt
# drwxr-sr-x  2 zwu09    datalab       4096 May  2 04:57 llm_diffuse_env
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 llvmlite
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 llvmlite-0.44.0.dist-info
# drwxr-sr-x  2 zwu09    datalab       4096 May  9 05:39 .local
# -rw-r--r--  1 zwu09    datalab     116559 May  9 05:42 MAIN.ipynb
# drwxr-sr-x  2 zwu09    datalab       4096 May  2 08:17 MAINWORKINGNOTEBOOK
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 narwhals
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 narwhals-1.37.1.dist-info
# drwxrwsr-x  2 zwu09    datalab       4096 May  2 08:26 notebooks
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 numba
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 numba-0.61.2.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:45 numpy
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 numpy-2.2.5.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 numpy.libs
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 packaging
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 packaging-25.0.dist-info
# drwxrwxr-x  2 zwu09    datalab       4096 May  2 07:50 pandas
# drwxrwxr-x  2 zwu09    datalab       4096 May  2 07:50 pandas-2.2.3.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 plotly
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 plotly-6.0.1.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 _plotly_utils
# -rw-r--r--  1 zwu09    datalab        284 May  2 07:25 processed_goodreads_reviews_with_tags.json
# drwxr-xr-x  2 zwu09    datalab       4096 Sep 11 19:20 __pycache__
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 pynndescent
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 pynndescent-0.5.13.dist-info
# drwxrwxr-x  2 zwu09    datalab       4096 May  2 07:50 python_dateutil-2.9.0.post0.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 pytz
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 pytz-2025.2.dist-info
# -rw-r--r--  1 zwu09    datalab       6007 May  2 07:28 raw_goodreads_reviews_output.json
# -rw-r--r--  1 zwu09    datalab     447784 May  2 04:17 robot_city.png
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 scikit_learn-1.6.1.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 scikit_learn.libs
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 scipy
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 scipy-1.15.2.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 scipy.libs
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 six-1.17.0.dist-info
# -rw-r--r--  1 zwu09    datalab      34703 May  2 08:44 six.py
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 sklearn
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 threadpoolctl-3.6.0.dist-info
# -rw-r--r--  1 zwu09    datalab      50722 May  2 08:44 threadpoolctl.py
# drwxrwsr-x  2 zwu09    datalab       4096 Sep 11 21:19 tmp
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 tqdm
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 tqdm-4.67.1.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 tzdata
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:44 tzdata-2025.2.dist-info
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 umap
# drwxr-xr-x  2 zwu09    datalab       4096 May  2 08:21 umap_learn-0.5.7.dist-info
# -rw-r--r--  1 zwu09    datalab       6009 May  2 03:45 Untitled10.ipynb
# -rw-r--r--  1 zwu09    datalab      58043 May  2 03:53 Untitled11.ipynb
# -rw-r--r--  1 zwu09    datalab      22833 Sep 11 17:34 Untitled12.ipynb
# -rw-r--r--  1 zwu09    datalab     802401 May  2 04:28 Untitled13.ipynb
# -rw-r--r--  1 zwu09    datalab       1415 May  2 04:50 Untitled14.ipynb
# -rw-r--r--  1 zwu09    datalab       2282 May  2 04:57 Untitled15.ipynb
# -rw-r--r--  1 zwu09    datalab         72 May  9 03:50 Untitled16.ipynb
# -rw-r--r--  1 zwu09    datalab         72 May  9 03:52 Untitled17.ipynb
# -rw-r--r--  1 zwu09    datalab        902 Sep 11 18:14 Untitled18.ipynb
# -rw-r--r--  1 zwu09    datalab        593 Sep 11 17:49 Untitled19.ipynb
# -rw-r--r--  1 zwu09    datalab      20799 Apr 22 20:56 Untitled1.ipynb
# -rw-r--r--  1 zwu09    datalab        555 Apr 23 19:10 Untitled2.ipynb
# -rw-r--r--  1 zwu09    datalab     166366 Apr 30 19:17 Untitled3.ipynb
# -rw-r--r--  1 zwu09    datalab      23985 May  2 01:49 Untitled4.ipynb
# -rw-r--r--  1 zwu09    datalab      34558 May  2 03:35 Untitled5.ipynb
# -rw-r--r--  1 zwu09    datalab        588 May  2 03:29 Untitled6.ipynb
# -rw-r--r--  1 zwu09    datalab        601 May  2 03:29 Untitled7.ipynb
# -rw-r--r--  1 zwu09    datalab         72 May  2 03:36 Untitled8.ipynb
# -rw-r--r--  1 zwu09    datalab      38477 May  2 03:43 Untitled9.ipynb
# drwxr-sr-x  2 zwu09    datalab       4096 May  2 09:39 Untitled Folder
# drwxr-sr-x  2 zwu09    datalab       4096 Sep 11 19:22 Untitled Folder 1
# drwxr-sr-x  2 zwu09    datalab       4096 Sep 11 19:22 Untitled Folder 2
# -rw-r--r--  1 zwu09    datalab       1414 Apr 23 19:10 Untitled.ipynb
# drwxr-sr-x  2 zwu09    datalab       4096 Sep 11 19:20 venv310
#
# === Directory sizes ===
# Failed to connect to the remote Jupyter Server 'http://localhost:8891/'. Verify the server is running and reachable.

# %%
# Set up cache directories to avoid filling home directory
import os
os.environ['HF_HOME'] = '/cluster/tufts/datalab/zwu09/caches/huggingface'
os.environ['TRANSFORMERS_CACHE'] = '/cluster/tufts/datalab/zwu09/caches/huggingface'
os.environ['PIP_CACHE_DIR'] = '/cluster/tufts/datalab/zwu09/caches/pip'
os.environ['TORCH_HOME'] = '/cluster/tufts/datalab/zwu09/caches/torch'
os.environ['TMPDIR'] = '/cluster/tufts/datalab/zwu09/tmp'

# Create cache directories
import subprocess
subprocess.run(['mkdir', '-p', os.environ['HF_HOME'], os.environ['PIP_CACHE_DIR'], os.environ['TORCH_HOME'], os.environ['TMPDIR']])

print("✅ Cache directories set up:")
print(f"HF_HOME: {os.environ['HF_HOME']}")
print(f"PIP_CACHE_DIR: {os.environ['PIP_CACHE_DIR']}")
print(f"TORCH_HOME: {os.environ['TORCH_HOME']}")
print(f"TMPDIR: {os.environ['TMPDIR']}")

# Install packages with explicit cache directory
# COMMENTED OUT FOR "RUN ALL" - Uncomment if you need to install packages
"""
print("\n📦 Installing packages to datalab...")
# %pip install --cache-dir /cluster/tufts/datalab/zwu09/caches/pip diffusers transformers accelerate safetensors bitsandbytes einops --quiet
"""

print("ℹ️  Package installation commented out for 'Run All'. Uncomment if needed.")
# Out:
# ✅ Cache directories set up:
# HF_HOME: /cluster/tufts/datalab/zwu09/caches/huggingface
# PIP_CACHE_DIR: /cluster/tufts/datalab/zwu09/caches/pip
# TORCH_HOME: /cluster/tufts/datalab/zwu09/caches/torch
# TMPDIR: /cluster/tufts/datalab/zwu09/tmp

# %%
# Clean up potential junk files
# !echo "=== Cleaning up potential junk ==="
# !echo "Checking for large files that can be deleted..."

# Check for large log files
# !find /cluster/tufts/datalab/zwu09 -name "*.log" -size +100M 2>/dev/null | head -5
# !echo ""

# Check for temporary files
# !find /cluster/tufts/datalab/zwu09 -name "*.tmp" -o -name "*.temp" -o -name "*~" 2>/dev/null | head -10
# !echo ""

# Check for old cache files
# !find /cluster/tufts/datalab/zwu09 -name "__pycache__" -type d 2>/dev/null | head -5
# !echo ""

# Check for large model files that might be duplicates
# !find /cluster/tufts/datalab/zwu09 -name "*.bin" -o -name "*.safetensors" -o -name "*.pt" -o -name "*.pth" 2>/dev/null | head -10
# !echo ""

print("💡 If you see large files above, you can delete them with:")
print("   rm -rf /path/to/large/file")
print("   find /cluster/tufts/datalab/zwu09 -name '__pycache__' -type d -exec rm -rf {} +")

# %%
# Stable Diffusion XL Demo - Generate AI Art!
# NOTE: Make sure packages are installed first by uncommenting the install cell above

try:
    from diffusers import DiffusionPipeline
    import torch
    
    print("🎨 Loading Stable Diffusion XL...")
    print("This may take a few minutes on first run (downloading model)")
    
    # Use a lightweight, fast model for testing
    model_id = "stabilityai/sdxl-turbo"  # Fast, lightweight SDXL variant
    
    # Load pipeline
    pipe = DiffusionPipeline.from_pretrained(
        model_id,
        torch_dtype=torch.float16,
        use_safetensors=True,
        variant="fp16"
    )
    
    # Move to GPU
    pipe = pipe.to("cuda")
    
    print("✅ Model loaded successfully!")
    print(f"Model: {model_id}")
    print(f"Device: {pipe.device}")
    
    # Generate an image
    prompt = "a beautiful landscape with mountains and a lake, digital art, high quality"
    print(f"\n🎨 Generating image with prompt: '{prompt}'")
    
    with torch.no_grad():
        image = pipe(prompt, num_inference_steps=4, guidance_scale=0.0).images[0]
    
    # Save the image
    output_path = "/cluster/tufts/datalab/zwu09/generated_art.png"
    image.save(output_path)
    print(f"✅ Image saved to: {output_path}")
    
    # Display the image
    from IPython.display import display, Image
    display(image)
    
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("💡 Solution: Uncomment the package installation cell above and run it first")
    print("   Then restart the kernel and run this cell again")
except Exception as e:
    print(f"❌ Error: {e}")
    print("💡 Make sure you're running on a GPU compute node with CUDA available")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Stable Diffusion XL Demo - Generate AI Art!
# ----> 2 from diffusers import DiffusionPipeline
#       3 import torch
#       5 print("🎨 Loading Stable Diffusion XL...")
#
# File ~/.local/lib/python3.12/site-packages/diffusers/__init__.py:5
#       1 __version__ = "0.27.2"
#       3 from typing import TYPE_CHECKING
# ----> 5 from .utils import (
#       6     DIFFUSERS_SLOW_IMPORT,
#       7     OptionalDependencyNotAvailable,
#       8     _LazyModule,
#       9     is_flax_available,
#      10     is_k_diffusion_available,
#      11     is_librosa_available,
#      12     is_note_seq_available,
#      13     is_onnx_available,
#      14     is_scipy_available,
#      15     is_torch_available,
#      16     is_torchsde_available,
#      17     is_transformers_available,
#      18 )
#      21 # Lazy Import based on
#      22 # https://github.com/huggingface/transformers/blob/main/src/transformers/__init__.py
#      23
#      24 # When adding a new object to this init, please add it to `_import_structure`. The `_import_structure` is a dictionary submodule to list of object names,
#      25 # and is used to defer the actual importing for when the objects are requested.
#      26 # This way `import diffusers` provides the names in the namespace without actually importing anything (and especially none of the backends).
#      28 _import_structure = {
#      29     "configuration_utils": ["ConfigMixin"],
#      30     "models": [],
#    (...)
#      50     ],
#      51 }
#
# File ~/.local/lib/python3.12/site-packages/diffusers/utils/__init__.py:38
#      36 from .deprecation_utils import deprecate
#      37 from .doc_utils import replace_example_docstring
# ---> 38 from .dynamic_modules_utils import get_class_from_dynamic_module
#      39 from .export_utils import export_to_gif, export_to_obj, export_to_ply, export_to_video
#      40 from .hub_utils import (
#      41     PushToHubMixin,
#      42     _add_variant,
#    (...)
#      45     http_user_agent,
#      46 )
#
# File ~/.local/lib/python3.12/site-packages/diffusers/utils/dynamic_modules_utils.py:28
#      25 from typing import Dict, Optional, Union
#      26 from urllib import request
# ---> 28 from huggingface_hub import cached_download, hf_hub_download, model_info
#      29 from huggingface_hub.utils import validate_hf_hub_args
#      30 from packaging import version
#
# ImportError: cannot import name 'cached_download' from 'huggingface_hub' (/cluster/home/zwu09/.local/lib/python3.12/site-packages/huggingface_hub/__init__.py)

# %%
# TinyLlama Demo - Chat with a Small Language Model
# NOTE: Make sure packages are installed first by uncommenting the install cell above

try:
    from transformers import AutoTokenizer, AutoModelForCausalLM
    import torch
    
    print("🤖 Loading TinyLlama...")
    print("This is a small but capable language model!")
    
    # Load model and tokenizer
    model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        torch_dtype=torch.float16,
        device_map="auto"
    )
    
    print("✅ TinyLlama loaded successfully!")
    
    # Chat function
    def chat_with_tinyllama(prompt, max_length=100):
        # Format prompt
        formatted_prompt = f"<|user|>\n{prompt}<|assistant|>\n"
        
        # Tokenize
        inputs = tokenizer(formatted_prompt, return_tensors="pt").to(model.device)
        
        # Generate
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=max_length,
                temperature=0.7,
                do_sample=True,
                pad_token_id=tokenizer.eos_token_id
            )
        
        # Decode response
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        # Extract just the assistant's response
        response = response.split("<|assistant|>")[-1].strip()
        
        return response
    
    # Test the model
    test_prompts = [
        "What is machine learning?",
        "Write a short poem about AI",
        "Explain quantum computing in simple terms"
    ]
    
    print("\n🤖 Testing TinyLlama:")
    for i, prompt in enumerate(test_prompts, 1):
        print(f"\n--- Test {i} ---")
        print(f"Human: {prompt}")
        response = chat_with_tinyllama(prompt)
        print(f"TinyLlama: {response}")
    
    print("\n✅ TinyLlama demo complete!")
    
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("💡 Solution: Uncomment the package installation cell above and run it first")
    print("   Then restart the kernel and run this cell again")
except Exception as e:
    print(f"❌ Error: {e}")
    print("💡 Make sure you're running on a GPU compute node with CUDA available")

# %%
# GPU Performance Benchmark
import torch
import time

print("⚡ GPU Performance Benchmark")
print("=" * 40)

# Test matrix multiplication performance
def benchmark_gpu():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")
    
    # Test different matrix sizes
    sizes = [1024, 2048, 4096]
    
    for size in sizes:
        print(f"\nTesting {size}x{size} matrices...")
        
        # Create random matrices
        a = torch.randn(size, size, device=device, dtype=torch.float32)
        b = torch.randn(size, size, device=device, dtype=torch.float32)
        
        # Warm up
        for _ in range(3):
            _ = torch.mm(a, b)
        
        # Benchmark
        torch.cuda.synchronize()
        start_time = time.time()
        
        for _ in range(10):
            result = torch.mm(a, b)
        
        torch.cuda.synchronize()
        end_time = time.time()
        
        avg_time = (end_time - start_time) / 10
        gflops = (2 * size**3) / (avg_time * 1e9)  # Approximate GFLOPS
        
        print(f"  Average time: {avg_time*1000:.2f} ms")
        print(f"  Approximate GFLOPS: {gflops:.2f}")

# Run benchmark
benchmark_gpu()

# Memory usage
print(f"\n💾 GPU Memory Usage:")
print(f"  Allocated: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
print(f"  Cached: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")

print("\n✅ Benchmark complete!")

# %% [markdown]
# ## 6. Interactive Demos
#
# Try these interactive demos! Run each cell to test different AI capabilities.

# %%
# Interactive Image Generation
def generate_custom_image(prompt, steps=4):
    """Generate an image with your custom prompt"""
    print(f"🎨 Generating: '{prompt}'")
    
    with torch.no_grad():
        image = pipe(prompt, num_inference_steps=steps, guidance_scale=0.0).images[0]
    
    # Save with timestamp
    import datetime
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"/cluster/tufts/datalab/zwu09/custom_art_{timestamp}.png"
    image.save(filename)
    
    print(f"✅ Saved to: {filename}")
    display(image)
    return image

# Try your own prompts!
# Uncomment and modify these examples:

# generate_custom_image("a futuristic city with flying cars, cyberpunk style")
# generate_custom_image("a cute robot playing with a cat, cartoon style")
# generate_custom_image("abstract art with vibrant colors and geometric shapes")

print("🎨 Ready for custom image generation!")
print("Use: generate_custom_image('your prompt here')")

# %%
# Interactive Chat with TinyLlama
def chat_interactive():
    """Interactive chat session with TinyLlama"""
    print("🤖 TinyLlama Chat - Type 'quit' to exit")
    print("=" * 50)
    
    while True:
        user_input = input("\nYou: ")
        if user_input.lower() in ['quit', 'exit', 'bye']:
            print("👋 Goodbye!")
            break
        
        try:
            response = chat_with_tinyllama(user_input, max_length=150)
            print(f"TinyLlama: {response}")
        except Exception as e:
            print(f"❌ Error: {e}")

# Uncomment to start interactive chat:
# chat_interactive()

print("🤖 Ready for interactive chat!")
print("Use: chat_interactive() to start chatting")

# %%
# Show ONLY your current jobs (zwu09)
# !echo "=== Your Current Jobs (zwu09 only) ==="
# !squeue -u zwu09
# !echo ""

# Count jobs by state for zwu09 only
# !echo "=== Job Summary (zwu09 only) ==="
# !squeue -u zwu09 --format="%.18i %.9P %.8j %.8u %.2t %.10M %.6D %R" --noheader | awk '{print $5}' | sort | uniq -c
# !echo ""

# Show detailed info for running jobs (zwu09 only)
# !echo "=== Running Job Details (zwu09 only) ==="
# !squeue -u zwu09 --format="%.18i %.9P %.8j %.8u %.2t %.10M %.6D %R" --noheader | grep ' R ' | while read line; do
!    jobid=$(echo $line | awk '{print $1}')
!    echo "Job $jobid:"
!    scontrol show jobid -dd $jobid | grep -E "(JobId|JobName|UserId|State|RunTime|TimeLimit|NodeList|NumNodes|NumCPUs|ReqMem|GRES)"
!    echo "---"
# !done
# Out:
# === Your Current Jobs (zwu09 only) ===
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#           15655472       gpu     bash    zwu09  R      11:08      1 cc1gpu005
#
# === Job Summary (zwu09 only) ===
#       1 R
#
# === Running Job Details (zwu09 only) ===
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# Job :
# JobId=9699735 JobName=launch_experiment.sh
#    UserId=areddy05(34017) GroupId=areddy05(7786) MCS_label=N/A
#    JobState=PENDING Reason=ReqNodeNotAvail,_May_be_reserved_for_other_job Dependency=(null)
#    RunTime=00:00:00 TimeLimit=00:15:00 TimeMin=N/A
#    ReqNodeList=p1cmp010 ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15579658 JobName=bash
#    UserId=zhuang12(31612) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=6-11:11:16 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp001
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp001 CPU_IDs=114-115 Mem=30720 GRES=
# JobId=15586676 JobName=run37
#    UserId=mzaidi01(31503) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-04:24:27 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp112
#    NumNodes=1 NumCPUs=110 NumTasks=110 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp112 CPU_IDs=0-81,98-125 Mem=819200 GRES=
# JobId=15586678 JobName=run38
#    UserId=mzaidi01(31503) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-05:37:43 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp084
#    NumNodes=1 NumCPUs=90 NumTasks=90 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp084 CPU_IDs=0-89 Mem=716800 GRES=
# JobId=15598955 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=4-06:56:08 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu004 ExcNodeList=(null)
#    NodeList=cc1gpu004
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu004 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:2)
# JobId=15598964 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=4-06:50:38 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu005 ExcNodeList=(null)
#    NodeList=cc1gpu005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu005 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15601931 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=4-00:57:21 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu001 ExcNodeList=(null)
#    NodeList=cc1gpu001
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu001 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15602490 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-23:22:11 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu002 ExcNodeList=(null)
#    NodeList=cc1gpu002
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu002 CPU_IDs=0-1,18-23 Mem=131072 GRES=gpu:a100:1(IDX:1)
# JobId=15603641 JobName=bash
#    UserId=zhuang12(31612) GroupId=student(6150) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-20:47:22 TimeLimit=5-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp073
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:p100:1
#      Nodes=p1cmp073 CPU_IDs=36-37 Mem=30720 GRES=gpu:p100:1(IDX:1)
# JobId=15606464 ArrayJobId=15605963 ArrayTaskId=500 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp011
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp011 CPU_IDs=0 Mem=4096 GRES=
# JobId=15606466 ArrayJobId=15605963 ArrayTaskId=502 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp011
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp011 CPU_IDs=2 Mem=4096 GRES=
# JobId=15606476 ArrayJobId=15605963 ArrayTaskId=512 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp011
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp011 CPU_IDs=12 Mem=4096 GRES=
# JobId=15606485 ArrayJobId=15605963 ArrayTaskId=521 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=4 Mem=4096 GRES=
# JobId=15606494 ArrayJobId=15605963 ArrayTaskId=530 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=13 Mem=4096 GRES=
# JobId=15606505 ArrayJobId=15605963 ArrayTaskId=541 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=24 Mem=4096 GRES=
# JobId=15606507 ArrayJobId=15605963 ArrayTaskId=543 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=26 Mem=4096 GRES=
# JobId=15606511 ArrayJobId=15605963 ArrayTaskId=547 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=30 Mem=4096 GRES=
# JobId=15606515 ArrayJobId=15605963 ArrayTaskId=551 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp004 CPU_IDs=34 Mem=4096 GRES=
# JobId=15606528 ArrayJobId=15605963 ArrayTaskId=564 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp005
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp005 CPU_IDs=2-3 Mem=4096 GRES=
# JobId=15606584 ArrayJobId=15605963 ArrayTaskId=620 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=3 Mem=4096 GRES=
# JobId=15606585 ArrayJobId=15605963 ArrayTaskId=621 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=6 Mem=4096 GRES=
# JobId=15606591 ArrayJobId=15605963 ArrayTaskId=627 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=12 Mem=4096 GRES=
# JobId=15606592 ArrayJobId=15605963 ArrayTaskId=628 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=13 Mem=4096 GRES=
# JobId=15606597 ArrayJobId=15605963 ArrayTaskId=633 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=18 Mem=4096 GRES=
# JobId=15606598 ArrayJobId=15605963 ArrayTaskId=634 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=19 Mem=4096 GRES=
# JobId=15606600 ArrayJobId=15605963 ArrayTaskId=636 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=21 Mem=4096 GRES=
# JobId=15606602 ArrayJobId=15605963 ArrayTaskId=638 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=23 Mem=4096 GRES=
# JobId=15606603 ArrayJobId=15605963 ArrayTaskId=639 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=24 Mem=4096 GRES=
# JobId=15606606 ArrayJobId=15605963 ArrayTaskId=642 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=27 Mem=4096 GRES=
# JobId=15606608 ArrayJobId=15605963 ArrayTaskId=644 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=29 Mem=4096 GRES=
# JobId=15606609 ArrayJobId=15605963 ArrayTaskId=645 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=30 Mem=4096 GRES=
# JobId=15606612 ArrayJobId=15605963 ArrayTaskId=648 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=33 Mem=4096 GRES=
# JobId=15606613 ArrayJobId=15605963 ArrayTaskId=649 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:54 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=34 Mem=4096 GRES=
# JobId=15606696 ArrayJobId=15605963 ArrayTaskId=731 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-11:17:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp016
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp016 CPU_IDs=4 Mem=4096 GRES=
# JobId=15605963 ArrayJobId=15605963 ArrayTaskId=961 JobName=CANUCS_MACS1149_QGs
#    UserId=rpan04(32255) GroupId=rpan04(5713) MCS_label=N/A
#    JobState=COMPLETED Reason=None Dependency=(null)
#    RunTime=00:00:04 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp012
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp012 CPU_IDs=58-59 Mem=4096 GRES=
# JobId=15608651 ArrayJobId=15608620 ArrayTaskId=9 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:48:47 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp036
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp036 CPU_IDs=54-61 Mem=20480 GRES=
# JobId=15609296 ArrayJobId=15608620 ArrayTaskId=24 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:04:35 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp013
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp013 CPU_IDs=82-89 Mem=20480 GRES=
# JobId=15609307 ArrayJobId=15608620 ArrayTaskId=28 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:02:35 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp012
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp012 CPU_IDs=60-63,110-113 Mem=20480 GRES=
# JobId=15609308 ArrayJobId=15608620 ArrayTaskId=29 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-08:02:35 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=2-3,10-15 Mem=20480 GRES=
# JobId=15610543 ArrayJobId=15609375 ArrayTaskId=5 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:14:04 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=40-47,52-55,112-115 Mem=20480 GRES=
# JobId=15610545 ArrayJobId=15609375 ArrayTaskId=7 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:14:04 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=56-65,94-97,100-101 Mem=20480 GRES=
# JobId=15610671 ArrayJobId=15609375 ArrayTaskId=9 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:10:03 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp013
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp013 CPU_IDs=18-19,100-113 Mem=20480 GRES=
# JobId=15610709 ArrayJobId=15609375 ArrayTaskId=23 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:04:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=64-69,72-77,88-89,92-93 Mem=20480 GRES=
# JobId=15610710 ArrayJobId=15609375 ArrayTaskId=24 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:04:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=0-3,6-17 Mem=20480 GRES=
# JobId=15610713 ArrayJobId=15609375 ArrayTaskId=27 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:04:02 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=84-99 Mem=20480 GRES=
# JobId=15610723 ArrayJobId=15609375 ArrayTaskId=30 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-07:02:01 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=40-55 Mem=20480 GRES=
# JobId=15610950 ArrayJobId=15609375 ArrayTaskId=36 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:25:51 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp006
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp006 CPU_IDs=52-55,58-63,78-79,94-95,122-123 Mem=20480 GRES=
# JobId=15610951 ArrayJobId=15609375 ArrayTaskId=37 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:25:51 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp010
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp010 CPU_IDs=4-7,20-25,28-33 Mem=20480 GRES=
# JobId=15610953 ArrayJobId=15609375 ArrayTaskId=39 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:25:51 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp022
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp022 CPU_IDs=0-3,16-19,38-45 Mem=20480 GRES=
# JobId=15610960 ArrayJobId=15609375 ArrayTaskId=41 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:23:51 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp022
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp022 CPU_IDs=46-59,86-87 Mem=20480 GRES=
# JobId=15611641 ArrayJobId=15609375 ArrayTaskId=43 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:05:46 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=0-1,8-9,18-21,24-25,30-31,52-55 Mem=20480 GRES=
# JobId=15611642 ArrayJobId=15609375 ArrayTaskId=44 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-06:05:46 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=18-29,54-57 Mem=20480 GRES=
# JobId=15612071 ArrayJobId=15609375 ArrayTaskId=46 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-05:45:44 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp017
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp017 CPU_IDs=38-39,82-95 Mem=20480 GRES=
# JobId=15612076 ArrayJobId=15609375 ArrayTaskId=49 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=3-05:43:43 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=6-9,14-15,20-21,28-33,36-37 Mem=20480 GRES=
# JobId=15609375 ArrayJobId=15609375 ArrayTaskId=57 JobName=run_getTT_sineFit2.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=COMPLETED Reason=None Dependency=(null)
#    RunTime=00:02:34 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=4-5,10-13,22-27,34-35,38-39 Mem=20480 GRES=
# JobId=15608620 ArrayJobId=15608620 ArrayTaskId=74 ArrayTaskThrottle=37 JobName=run_search_ANTIC.sh
#    UserId=tklean01(34448) GroupId=tklean01(8244) MCS_label=N/A
#    JobState=FAILED Reason=NonZeroExitCode Dependency=(null)
#    RunTime=00:00:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp033
#    NumNodes=1 NumCPUs=8 NumTasks=1 CPUs/Task=8 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp033 CPU_IDs=64-65,70-73,78-79 Mem=20480 GRES=
# JobId=15615967 JobName=1_2a_NG15_more
#    UserId=amalna01(33643) GroupId=amalna01(7236) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-11:23:35 TimeLimit=6-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp041
#    NumNodes=1 NumCPUs=3 NumTasks=3 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp041 CPU_IDs=120-121,124-125 Mem=102400 GRES=
# JobId=15616459 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:02:39 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=s1cmp004 ExcNodeList=(null)
#    NodeList=s1cmp004
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp004 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15616460 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:02:39 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=s1cmp001 ExcNodeList=(null)
#    NodeList=s1cmp001
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp001 CPU_IDs=0-7 Mem=131072 GRES=gpu:a100:1(IDX:0)
# JobId=15616461 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:59:59 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=s1cmp005 ExcNodeList=(null)
#    NodeList=s1cmp005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp005 CPU_IDs=80-81,86-87,94-95,110-111 Mem=131072 GRES=gpu:a100:1(IDX:5)
# JobId=15617153 JobName=sys/dashboard/sys/jupyternotebook
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-10:05:39 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp010
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp010 CPU_IDs=22-25 Mem=16000 GRES=
# JobId=15617199 ArrayJobId=15617196 ArrayTaskId=3 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp036
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp036 CPU_IDs=20-21,42-43,46-53,114-117 Mem=20480 GRES=
# JobId=15617205 ArrayJobId=15617196 ArrayTaskId=9 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp039
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp039 CPU_IDs=8-9,84-87,94-103 Mem=20480 GRES=
# JobId=15617206 ArrayJobId=15617196 ArrayTaskId=10 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp040
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp040 CPU_IDs=0-1,8-11,16-17,22-27,30-31 Mem=20480 GRES=
# JobId=15617208 ArrayJobId=15617196 ArrayTaskId=12 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp021
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp021 CPU_IDs=74-75,90-91,98-109 Mem=20480 GRES=
# JobId=15617210 ArrayJobId=15617196 ArrayTaskId=14 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp021
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp021 CPU_IDs=38-51,62-63 Mem=20480 GRES=
# JobId=15617214 ArrayJobId=15617196 ArrayTaskId=18 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp043
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp043 CPU_IDs=0-5,16-23,30-31 Mem=20480 GRES=
# JobId=15617218 ArrayJobId=15617196 ArrayTaskId=22 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp045
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp045 CPU_IDs=16-31 Mem=20480 GRES=
# JobId=15617220 ArrayJobId=15617196 ArrayTaskId=24 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp001
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp001 CPU_IDs=2-11,14-19 Mem=20480 GRES=
# JobId=15617223 ArrayJobId=15617196 ArrayTaskId=27 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp001
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp001 CPU_IDs=56-67,76-77,84-85 Mem=20480 GRES=
# JobId=15617224 ArrayJobId=15617196 ArrayTaskId=28 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=2-5,8-11,22-29 Mem=20480 GRES=
# JobId=15617225 ArrayJobId=15617196 ArrayTaskId=29 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=30-37,40-47 Mem=20480 GRES=
# JobId=15617226 ArrayJobId=15617196 ArrayTaskId=30 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=64-79 Mem=20480 GRES=
# JobId=15617228 ArrayJobId=15617196 ArrayTaskId=32 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=96-111 Mem=20480 GRES=
# JobId=15617229 ArrayJobId=15617196 ArrayTaskId=33 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp002
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp002 CPU_IDs=48-49,56-63,112-117 Mem=20480 GRES=
# JobId=15617230 ArrayJobId=15617196 ArrayTaskId=34 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=2-3,22-35 Mem=20480 GRES=
# JobId=15617231 ArrayJobId=15617196 ArrayTaskId=35 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=36-39,50-51,62-63,90-91,94-95,98-99,120-121 Mem=20480 GRES=
# JobId=15617233 ArrayJobId=15617196 ArrayTaskId=37 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=38-39,50-51,90-91,102-105,110-115 Mem=20480 GRES=
# JobId=15617234 ArrayJobId=15617196 ArrayTaskId=38 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=66-71,74-81,84-85 Mem=20480 GRES=
# JobId=15617235 ArrayJobId=15617196 ArrayTaskId=39 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=42-49,58-59,102-105,114-115 Mem=20480 GRES=
# JobId=15617236 ArrayJobId=15617196 ArrayTaskId=40 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-09:48:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp033
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp033 CPU_IDs=2-13,16-19 Mem=20480 GRES=
# JobId=15617196 ArrayJobId=15617196 ArrayTaskId=69 JobName=run_getTT_sineFit.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=FAILED Reason=NonZeroExitCode Dependency=(null)
#    RunTime=00:00:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=0-5,10-13,16-19,22-23 Mem=20480 GRES=
# JobId=15617687 JobName=sys/dashboard/sys/jupyterlab
#    UserId=lbhara01(34408) GroupId=lbhara01(8198) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-08:42:31 TimeLimit=4-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp010
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp010 CPU_IDs=20 Mem=32000 GRES=
# JobId=15623109 JobName=1_2a_NG15_more1
#    UserId=amalna01(33643) GroupId=amalna01(7236) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=2-03:26:44 TimeLimit=6-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp009
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=s1cmp009 CPU_IDs=122-123 Mem=20480 GRES=
# JobId=15634230 JobName=1_2a_NG15_more2
#    UserId=amalna01(33643) GroupId=amalna01(7236) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-10:59:43 TimeLimit=6-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp053
#    NumNodes=1 NumCPUs=5 NumTasks=5 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp053 CPU_IDs=50-55 Mem=102400 GRES=
# JobId=15634410 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-10:19:12 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu001 ExcNodeList=(null)
#    NodeList=cc1gpu001
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu001 CPU_IDs=56-63 Mem=131072 GRES=gpu:a100:1(IDX:1)
# JobId=15634970 JobName=bash
#    UserId=jhu08(31966) GroupId=jhu08(5420) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-09:05:06 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=cc1gpu005 ExcNodeList=(null)
#    NodeList=cc1gpu005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu005 CPU_IDs=56-63 Mem=131072 GRES=gpu:a100:1(IDX:2)
# JobId=15635375 ArrayJobId=15635246 ArrayTaskId=2 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-09:15:09 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp032
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp032 CPU_IDs=30-41,50-53,64-65,72-73,82-83,86-95 Mem=20480 GRES=
# JobId=15636317 ArrayJobId=15635246 ArrayTaskId=3 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:26:38 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp012
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp012 CPU_IDs=4-5,8-11,18-19,42-47,52-53,58-59,90-93,106-109,114-119 Mem=20480 GRES=
# JobId=15635558 JobName=sys/dashboard/sys/jupyternotebook
#    UserId=jlin20(33203) GroupId=jlin20(5951) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-08:59:26 TimeLimit=5-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp008
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp008 CPU_IDs=0-3 Mem=110000 GRES=
# JobId=15636313 JobName=Etran_SKCongWRlayerN
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:26:52 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp005 CPU_IDs=52-59 Mem=65536 GRES=gpu:a100:1(IDX:4)
# JobId=15636320 JobName=Etran_SKCongWRlayerN
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:25:49 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp005
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp005 CPU_IDs=44-51 Mem=65536 GRES=gpu:a100:1(IDX:2)
# JobId=15636351 ArrayJobId=15635246 ArrayTaskId=5 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:16:35 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp011
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp011 CPU_IDs=14-17,22-23,34-35,44-47,56-63,68-71,86-87,96-97,102-103,108-109 Mem=20480 GRES=
# JobId=15636416 ArrayJobId=15635246 ArrayTaskId=7 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:06:32 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp030
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp030 CPU_IDs=6-17,48-49,56-59,78-79,82-83,96-97,102-109 Mem=20480 GRES=
# JobId=15636417 ArrayJobId=15635246 ArrayTaskId=8 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:06:32 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp031
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp031 CPU_IDs=4-7,16-17,22-23,26-29,32-37,42-47,76-77,80-81,88-89,98-99 Mem=20480 GRES=
# JobId=15636441 ArrayJobId=15635246 ArrayTaskId=10 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:02:31 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp019
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp019 CPU_IDs=0-3,14-15,22-27,36-39,58-59,64-69,72-75,82-85 Mem=20480 GRES=
# JobId=15636449 ArrayJobId=15635246 ArrayTaskId=11 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-07:00:30 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp008
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp008 CPU_IDs=4-5,10-11,24-27,34-35,38-39,66-69,80-83,100-103,106-113 Mem=20480 GRES=
# JobId=15636582 ArrayJobId=15635246 ArrayTaskId=12 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:40:27 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp065
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp065 CPU_IDs=2-3,10-13,16-17,20-23,26-33,36-37,40-41,50-51,60-65 Mem=20480 GRES=
# JobId=15636648 ArrayJobId=15635246 ArrayTaskId=15 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:34:25 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp007
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp007 CPU_IDs=0-5,26-27,32-33,36-37,40-41,54-55,90-105 Mem=20480 GRES=
# JobId=15636760 ArrayJobId=15635246 ArrayTaskId=17 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:22:23 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp014
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp014 CPU_IDs=0-31 Mem=20480 GRES=
# JobId=15636761 ArrayJobId=15635246 ArrayTaskId=18 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:22:23 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp016
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp016 CPU_IDs=0-31 Mem=20480 GRES=
# JobId=15636762 ArrayJobId=15635246 ArrayTaskId=19 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:22:23 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp036
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp036 CPU_IDs=18-19,64-93 Mem=20480 GRES=
# JobId=15636772 ArrayJobId=15635246 ArrayTaskId=20 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-06:20:23 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp005
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp005 CPU_IDs=0-1,24-25,32-37,42-43,64-65,68-71,76-89 Mem=20480 GRES=
# JobId=15636960 ArrayJobId=15635246 ArrayTaskId=22 JobName=run_getSigma_and_analysis_sineFit_A14.sh
#    UserId=ctubth01(33679) GroupId=ctubth01(7274) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-05:46:16 TimeLimit=3-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp016
#    NumNodes=1 NumCPUs=32 NumTasks=1 CPUs/Task=32 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp016 CPU_IDs=32-39,42-43,48-49,52-67,76-79 Mem=20480 GRES=
# JobId=15636970 JobName=ImperfectCSI
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-05:45:11 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=cc1gpu004
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu004 CPU_IDs=56-63 Mem=65536 GRES=gpu:a100:1(IDX:1)
# JobId=15636979 JobName=UA_GumbelSoftmax
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=1-05:44:29 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=cc1gpu002
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=cc1gpu002 CPU_IDs=2-9 Mem=65536 GRES=gpu:a100:1(IDX:0)
# JobId=15636985 JobName=ImperfectCSI
#    UserId=qlyu01(33578) GroupId=qlyu01(7170) MCS_label=N/A
# ...
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655478 ArrayJobId=15653485 ArrayTaskId=210 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:09:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp050
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:l40:1
#      Nodes=d1cmp050 CPU_IDs=112-113 Mem=32768 GRES=gpu:l40:1(IDX:0)
# JobId=15655482 ArrayJobId=15653485 ArrayTaskId=211 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:08:49 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp001
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp001 CPU_IDs=80-81 Mem=32768 GRES=gpu:a100:1(IDX:3)
# JobId=15655479 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655480 JobName=T_Find_ANN_1K_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15652425 ArrayJobId=15652425 ArrayTaskId=2 JobName=transjob_05_059_2025_JulAug.sh
#    UserId=acampi02(33741) GroupId=acampi02(7344) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:08:40 TimeLimit=08:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp[001-002,005-007,009,012-015,021-023,038-040]
#    NumNodes=16 NumCPUs=16 NumTasks=16 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp001 CPU_IDs=28-29 Mem=32768 GRES=
#      Nodes=d1cmp002 CPU_IDs=94-95 Mem=32768 GRES=
#      Nodes=d1cmp005 CPU_IDs=12-13 Mem=32768 GRES=
#      Nodes=d1cmp006 CPU_IDs=8-9 Mem=32768 GRES=
#      Nodes=d1cmp007 CPU_IDs=64-65 Mem=32768 GRES=
#      Nodes=d1cmp009 CPU_IDs=74-75 Mem=32768 GRES=
#      Nodes=d1cmp012 CPU_IDs=100-101 Mem=32768 GRES=
#      Nodes=d1cmp013 CPU_IDs=36-37 Mem=32768 GRES=
#      Nodes=d1cmp014 CPU_IDs=76-77 Mem=32768 GRES=
#      Nodes=d1cmp015 CPU_IDs=36-37 Mem=32768 GRES=
#      Nodes=d1cmp021 CPU_IDs=58-59 Mem=32768 GRES=
#      Nodes=d1cmp022 CPU_IDs=26-27 Mem=32768 GRES=
#      Nodes=d1cmp023 CPU_IDs=116-117 Mem=32768 GRES=
#      Nodes=d1cmp038 CPU_IDs=8-9 Mem=32768 GRES=
#      Nodes=d1cmp039 CPU_IDs=20-21 Mem=32768 GRES=
#      Nodes=d1cmp040 CPU_IDs=66-67 Mem=32768 GRES=
# JobId=15655488 ArrayJobId=15653485 ArrayTaskId=212 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:07:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp007
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp007 CPU_IDs=72-73 Mem=32768 GRES=gpu:a100:1(IDX:1)
# JobId=15655483 JobName=A_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655484 JobName=A_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655485 JobName=A_Find_ANN_1K_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655486 ArrayJobId=15655486 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655487 JobName=A_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655490 ArrayJobId=15653485 ArrayTaskId=213 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:06:49 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp006
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp006 CPU_IDs=88-89 Mem=32768 GRES=gpu:a100:1(IDX:1)
# JobId=15655489 ArrayJobId=15655489 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655492 ArrayJobId=15653485 ArrayTaskId=214 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:06:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp003
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp003 CPU_IDs=0-1 Mem=32768 GRES=gpu:a100:1(IDX:0)
# JobId=15655491 JobName=A_Find_ANN_1K_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:2
# JobId=15655493 ArrayJobId=15653485 ArrayTaskId=215 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:06:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp004
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp004 CPU_IDs=56-57 Mem=32768 GRES=gpu:a100:1(IDX:1)
# JobId=15655496 ArrayJobId=15653485 ArrayTaskId=216 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:05:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp015
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:rtx_a5000:1
#      Nodes=s1cmp015 CPU_IDs=0-1 Mem=32768 GRES=gpu:rtx_a5000:1(IDX:1)
# JobId=15655494 JobName=T_Find_ANN_1K_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655513 ArrayJobId=15653485 ArrayTaskId=217 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:00:13 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp007
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:a100:1
#      Nodes=s1cmp007 CPU_IDs=84-85 Mem=32768 GRES=gpu:a100:1(IDX:0)
# JobId=15655497 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655498 ArrayJobId=15655498 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655500 ArrayJobId=15655500 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655501 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655502 JobName=vscode.slurm
#    UserId=kheuto01(32122) GroupId=kheuto01(5594) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:03:13 TimeLimit=13:25:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=s1cmp013
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=gpu:rtx_a5000:1
#      Nodes=s1cmp013 CPU_IDs=0-1,64-65 Mem=256000 GRES=gpu:rtx_a5000:1(IDX:0)
# JobId=15655503 JobName=T_Find_ANN_1K3L_SelfLoadDB
#    UserId=hhazan01(31619) GroupId=hhazan01(7472) MCS_label=N/A
#    JobState=PENDING Reason=QOSMaxMemoryPerUser Dependency=(null)
#    RunTime=00:00:00 TimeLimit=1-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=d1cmp007,s1cmp[010-011,013,015]
#    NodeList=
#    NumNodes=1 NumCPUs=4 NumTasks=1 CPUs/Task=4 ReqB:S:C:T=0:0:*:2
# JobId=15655504 ArrayJobId=15655504 ArrayTaskId=1-6 JobName=picc-rl-array
#    UserId=bmille12(34074) GroupId=bmille12(7856) MCS_label=N/A
#    JobState=PENDING Reason=Resources Dependency=(null)
#    RunTime=00:00:00 TimeLimit=06:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList= SchedNodeList=d1cmp016
#    NumNodes=1 NumCPUs=128 NumTasks=1 CPUs/Task=128 ReqB:S:C:T=0:0:*:*
# JobId=15652426 ArrayJobId=15652426 ArrayTaskId=2 JobName=transjob_05_060_2025_JulAug.sh
#    UserId=acampi02(33741) GroupId=acampi02(7344) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:02:48 TimeLimit=08:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp[005-007,010-015,021-022,035,038-040],p1cmp045
#    NumNodes=16 NumCPUs=16 NumTasks=16 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp005 CPU_IDs=38-39 Mem=32768 GRES=
#      Nodes=d1cmp006 CPU_IDs=20-21 Mem=32768 GRES=
#      Nodes=d1cmp007 CPU_IDs=16-17 Mem=32768 GRES=
#      Nodes=d1cmp010 CPU_IDs=60-61 Mem=32768 GRES=
#      Nodes=d1cmp011 CPU_IDs=122-123 Mem=32768 GRES=
#      Nodes=d1cmp012 CPU_IDs=82-83 Mem=32768 GRES=
#      Nodes=d1cmp013 CPU_IDs=24-25 Mem=32768 GRES=
#      Nodes=d1cmp014 CPU_IDs=94-95 Mem=32768 GRES=
#      Nodes=d1cmp015 CPU_IDs=62-63 Mem=32768 GRES=
#      Nodes=d1cmp021 CPU_IDs=60-61 Mem=32768 GRES=
#      Nodes=d1cmp022 CPU_IDs=34-35 Mem=32768 GRES=
#      Nodes=d1cmp035 CPU_IDs=4-5 Mem=32768 GRES=
#      Nodes=d1cmp038 CPU_IDs=40-41 Mem=32768 GRES=
#      Nodes=d1cmp039 CPU_IDs=16-17 Mem=32768 GRES=
#      Nodes=d1cmp040 CPU_IDs=72-73 Mem=32768 GRES=
#      Nodes=p1cmp045 CPU_IDs=10-11 Mem=32768 GRES=
# JobId=15655506 ArrayJobId=15655506 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655508 JobName=nf-humann_(humann_on_FG00004_S26)
#    UserId=dpinto02(34799) GroupId=dpinto02(8620) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:00:48 TimeLimit=08:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp018
#    NumNodes=1 NumCPUs=16 NumTasks=1 CPUs/Task=16 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp018 CPU_IDs=0-15 Mem=32768 GRES=
# JobId=15655509 ArrayJobId=15655509 ArrayTaskId=1 JobName=abc_array
#    UserId=dwuitc01(34390) GroupId=dwuitc01(8178) MCS_label=N/A
#    JobState=PENDING Reason=Priority Dependency=(null)
#    RunTime=00:00:00 TimeLimit=2-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15652427 ArrayJobId=15652427 ArrayTaskId=2 JobName=transjob_05_061_2025_JulAug.sh
#    UserId=acampi02(33741) GroupId=acampi02(7344) MCS_label=N/A
#    JobState=PENDING Reason=Nodes_required_for_job_are_DOWN,_DRAINED_or_reserved_for_jobs_in_higher_priority_partitions Dependency=(null)
#    RunTime=00:00:00 TimeLimit=08:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=16-16 NumCPUs=16 NumTasks=16 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# JobId=15655511 JobName=sys/dashboard/sys/jupyternotebook
#    UserId=eharve06(32875) GroupId=eharve06(6607) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:00:31 TimeLimit=12:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=p1cmp010
#    NumNodes=1 NumCPUs=4 NumTasks=4 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=p1cmp010 CPU_IDs=18-19,21,26 Mem=16000 GRES=
# JobId=15655512 JobName=sys/dashboard/sys/jupyter_class
#    UserId=hlee37(34735) GroupId=hlee37(8554) MCS_label=N/A
#    JobState=RUNNING Reason=None Dependency=(null)
#    RunTime=00:00:25 TimeLimit=04:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=d1cmp035
#    NumNodes=1 NumCPUs=2 NumTasks=2 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    JOB_GRES=(null)
#      Nodes=d1cmp035 CPU_IDs=2-3 Mem=1000 GRES=
# JobId=15653485 ArrayJobId=15653485 ArrayTaskId=218-499%16 ArrayTaskThrottle=16 JobName=ppifold_array
#    UserId=jbouch03(33793) GroupId=jbouch03(7405) MCS_label=N/A
#    JobState=PENDING Reason=JobArrayTaskLimit Dependency=(null)
#    RunTime=00:00:00 TimeLimit=7-00:00:00 TimeMin=N/A
#    ReqNodeList=(null) ExcNodeList=(null)
#    NodeList=
#    NumNodes=1 NumCPUs=1 NumTasks=1 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
# ---
# /bin/bash: -c: line 0: syntax error near unexpected token `done'
# /bin/bash: -c: line 0: `done'
